# %%
import pandas

# %%
df1 = pandas.read_csv('supermarkets.csv')
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
from geopy.geocoders import ArcGIS

# %%
arc = ArcGIS()
loc1 = arc.geocode("3995 23rd St, San Francisco, CA 94114")
loc1
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
loc2 = arc.geocode("735 asfd St, San Francidddsdco, CA 94f119")
print(loc2)
# Out:
# None

# %%
(loc1.latitude, loc1.latitude)
# Out:
# (37.75292099814533, 37.75292099814533)

# %%
df1["FullAddress"]=df1["Address"] + ", " + df1["City"] + ", " + df1["State"]
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                   FullAddress
# 0          8         3666 21st St, San Francisco, CA 94114
# 1         15       735 Dolores St, San Francisco, CA 94119
# 2         25  332 Hill St, San Francisco, California 94114
# 3         10         3995 23rd St, San Francisco, CA 94114
# 4         12    1056 Sanchez St, San Francisco, California
# 5         20      551 Alvarado St, San Francisco, CA 94114

# %%
df1["Coordinates"] = df1["FullAddress"].apply(arc.geocode)
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                   FullAddress  \
# 0          8         3666 21st St, San Francisco, CA 94114
# 1         15       735 Dolores St, San Francisco, CA 94119
# 2         25  332 Hill St, San Francisco, California 94114
# 3         10         3995 23rd St, San Francisco, CA 94114
# 4         12    1056 Sanchez St, San Francisco, California
# 5         20      551 Alvarado St, San Francisco, CA 94114
#
# ...

# %%
df1["Latitude"] = df1["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                   FullAddress  \
# 0          8         3666 21st St, San Francisco, CA 94114
# 1         15       735 Dolores St, San Francisco, CA 94119
# 2         25  332 Hill St, San Francisco, California 94114
# 3         10         3995 23rd St, San Francisco, CA 94114
# 4         12    1056 Sanchez St, San Francisco, California
# 5         20      551 Alvarado St, San Francisco, CA 94114
#
# ...
